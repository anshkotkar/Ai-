# %%
# importing the libraries

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataset
df = pd.read_csv("C:/Users/Ansh/Downloads/Diwali Sales Data.csv", encoding = 'unicode_escape')
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group   Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35  28.0               0
# 1      1000732       Kartik  P00110942      F     26-35  35.0               1
# 2      1001990        Bindu  P00118542      F     26-35  35.0               1
# 3      1001425       Sudevi  P00237842      M      0-17  16.0               0
# 4      1000588         Joni  P00057942      M     26-35  28.0               1
# ...        ...          ...        ...    ...       ...   ...             ...
# 11246  1000695      Manning  P00296942      M     18-25  19.0               1
# 11247  1004089  Reichenbach  P00171342      M     26-35  33.0               0
# 11248  1001209        Oshin  P00201342      F     36-45  40.0               0
# 11249  1004023       Noonan  P00059442      M     36-45  37.0               0
# 11250  1002744      Brumley  P00281742      F     18-25  19.0               0
#
# ...

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group   Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35  28.0               0
# 1  1000732     Kartik  P00110942      F     26-35  35.0               1
# 2  1001990      Bindu  P00118542      F     26-35  35.0               1
# 3  1001425     Sudevi  P00237842      M      0-17  16.0               0
# 4  1000588       Joni  P00057942      M     26-35  28.0               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto     1.0
# 1  Andhra Pradesh  Southern             Govt             Auto     3.0
# 2   Uttar Pradesh   Central       Automobile             Auto     3.0
# 3       Karnataka  Southern     Construction             Auto     2.0
# 4         Gujarat   Western  Food Processing             Auto     2.0
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.tail()
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group   Age  Marital_Status  \
# 11246  1000695      Manning  P00296942      M     18-25  19.0               1
# 11247  1004089  Reichenbach  P00171342      M     26-35  33.0               0
# 11248  1001209        Oshin  P00201342      F     36-45  40.0               0
# 11249  1004023       Noonan  P00059442      M     36-45  37.0               0
# 11250  1002744      Brumley  P00281742      F     18-25  19.0               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount  \
# 11246     Maharashtra   Western     Chemical           Office     4.0   370.0
# 11247         Haryana  Northern   Healthcare       Veterinary     3.0   367.0
# 11248  Madhya Pradesh   Central      Textile           Office     4.0   213.0
# 11249       Karnataka  Southern  Agriculture           Office     3.0   206.0
# 11250     Maharashtra   Western   Healthcare           Office     3.0   188.0
#
#        Status  unnamed1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11249 non-null  float64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11250 non-null  float64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 1.3+ MB

# %%
# we drop two columns which are not needed

df.drop(['Status','unnamed1'], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11249 non-null  float64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11250 non-null  float64
#  12  Amount            11239 non-null  float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
pd.isnull(df)
# here False means not null
# True means there is null value
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
# use to see number of null values in columns
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  2
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               1
# Amount              12
# dtype: int64

# %%
df.shape
# Out:
# (11251, 13)

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11236 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11236 non-null  int64
#  1   Cust_name         11236 non-null  object
#  2   Product_ID        11236 non-null  object
#  3   Gender            11236 non-null  object
#  4   Age Group         11236 non-null  object
#  5   Age               11236 non-null  float64
#  6   Marital_Status    11236 non-null  int64
#  7   State             11236 non-null  object
#  8   Zone              11236 non-null  object
#  9   Occupation        11236 non-null  object
#  10  Product_Category  11236 non-null  object
#  11  Orders            11236 non-null  float64
#  12  Amount            11236 non-null  float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.2+ MB

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
# changing datatype of Amount column from float to int
df['Amount'] = df['Amount'].astype('int')

# %%
df['Amount'].dtype
# Out:
# dtype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11236 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11236 non-null  int64
#  1   Cust_name         11236 non-null  object
#  2   Product_ID        11236 non-null  object
#  3   Gender            11236 non-null  object
#  4   Age Group         11236 non-null  object
#  5   Age               11236 non-null  float64
#  6   Marital_Status    11236 non-null  int64
#  7   State             11236 non-null  object
#  8   Zone              11236 non-null  object
#  9   Occupation        11236 non-null  object
#  10  Product_Category  11236 non-null  object
#  11  Orders            11236 non-null  float64
#  12  Amount            11236 non-null  int32
# dtypes: float64(2), int32(1), int64(2), object(8)
# memory usage: 1.2+ MB

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
# rename column

df.rename(columns = {'Marital_Status' : 'Shaadi'})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group   Age  Shaadi  \
# 0      1002903    Sanskriti  P00125942      F     26-35  28.0       0
# 1      1000732       Kartik  P00110942      F     26-35  35.0       1
# 2      1001990        Bindu  P00118542      F     26-35  35.0       1
# 3      1001425       Sudevi  P00237842      M      0-17  16.0       0
# 4      1000588         Joni  P00057942      M     26-35  28.0       1
# ...        ...          ...        ...    ...       ...   ...     ...
# 11246  1000695      Manning  P00296942      M     18-25  19.0       1
# 11247  1004089  Reichenbach  P00171342      M     26-35  33.0       0
# 11248  1001209        Oshin  P00201342      F     36-45  40.0       0
# 11249  1004023       Noonan  P00059442      M     36-45  37.0       0
# 11250  1002744      Brumley  P00281742      F     18-25  19.0       0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123600e+04  11236.000000    11236.000000  11236.000000  11236.000000
# mean   1.003003e+06     35.409487        0.420078      2.489676   9449.884834
# std    1.715989e+03     12.754367        0.493593      1.115087   5218.071004
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001491e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12671.500000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
# Histograph

# %%
import matplotlib.pyplot as plt 

plt.hist(df["Age"])

# observation - which age group has spend how much money on shopping
# Out:
# (array([ 748., 2353., 3635., 1769., 1634.,  712.,  102.,   90.,   85.,
#          108.]),
#  array([12., 20., 28., 36., 44., 52., 60., 68., 76., 84., 92.]),
#  <BarContainer object of 10 artists>)

# %%
count_gender = df["Gender"].value_counts()   # .values_counts() = use to fine the number of perticular categori
print(count_gender)
# Out:
# F    7830
# M    3406
# Name: Gender, dtype: int64

# %%
# Gender

ax = sns.countplot(x='Gender',data=df)

# female order much compare to male

# %%
# Age

ax = sns.countplot(x= 'Age Group', data = df)

# %%
# Marital status
ax = sns.countplot(data=df, x = 'Marital_Status')

# %%
# occupation
sns.set(rc={'figure.figsize':(20,5)})

ax = sns.countplot(data=df,x='Occupation')
